# %%
import pandas as pd
import re

datas = open('C:\\Users\\a\\WhatsApp Chat with PTDORM.txt',encoding='utf-8')
datas

messages = []
dates = []

pattern = r'(\d{2}/\d{2}/\d{4}, \d{1,2}:\d{2}\u202f[ap]m) - (.+)'

for data in datas:
    message_match = re.match(pattern, data)
    if message_match:
        date = message_match.group(1)
        message = message_match.group(2)
        dates.append(date)
        messages.append(message)

# Create DataFrame
df = pd.DataFrame({'user_message': messages, 'message_date': dates})
cleaned_messages = []

for message in df['user_message']:
    cleaned_message = re.sub(r'^\w+\s\w+:\s', '', message)
    cleaned_messages.append(cleaned_message)

df['message'] = cleaned_messages

users = []
for message in df["user_message"]:
    match = re.match(r'^(.*?):', message)
    if match:
        user = match.group(1)
        users.append(user)
    else:
        user = "group_notification"
        users.append(user)

df['user'] = users

# df.drop(columns={'user_message'})


from datetime import datetime
df['message_date'] = pd.to_datetime(df['message_date'], format='%d/%m/%Y, %I:%M %p')
df['year'] = df['message_date'].dt.year
df['message_date'] = pd.to_datetime(df['message_date'], format='%d/%m/%Y, %I:%M %p')
df['month'] = df['message_date'].dt.month_name()
df['day'] = df['message_date'].dt.day
df['hour'] = df['message_date'].dt.hour
df['minute'] = df['message_date'].dt.minute
df
# Out:
#                                           user_message        message_date  \
# 0                 Group creator created group "PTDORM" 2022-12-18 13:19:00
# 1                                       You were added 2022-12-18 13:19:00
# 2    Sayeed Hossain: Logo'r sathe theme ta jacce na... 2023-04-18 01:54:00
# 3                Sayeed Hossain: Make it more natural😅 2023-04-18 01:55:00
# 4                          Akash Ghosh: Mese keo asen? 2023-04-18 15:25:00
# ..                                                 ...                 ...
# 913  Ratul: Vai meal debo apnar ajke raat e??@88016... 2023-08-28 17:36:00
# 914                               Prottoy Vai Asl: nah 2023-08-28 17:38:00
# 915  Badhon Vai: https://fb.watch/mIEV565mlr/?mibex... 2023-08-29 00:39:00
# 916                   Prottoy Vai Asl: <Media omitted> 2023-08-29 00:46:00
# 917                   Prottoy Vai Asl: <Media omitted> 2023-08-29 00:51:00
#
#                                                message                user  \
# 0                 Group creator created group "PTDORM"  group_notification
# 1                                       You were added  group_notification
# 2                    Logo'r sathe theme ta jacce na...      Sayeed Hossain
# 3                                Make it more natural😅      Sayeed Hossain
# 4                                       Mese keo asen?         Akash Ghosh
# ..                                                 ...                 ...
# 913  Ratul: Vai meal debo apnar ajke raat e??@88016...               Ratul
# 914                               Prottoy Vai Asl: nah     Prottoy Vai Asl
# 915       https://fb.watch/mIEV565mlr/?mibextid=Nif5oz          Badhon Vai
# 916                   Prottoy Vai Asl: <Media omitted>     Prottoy Vai Asl
# 917                   Prottoy Vai Asl: <Media omitted>     Prottoy Vai Asl
#
#      year     month  day  hour  minute
# 0    2022  December   18    13      19
# 1    2022  December   18    13      19
# 2    2023     April   18     1      54
# 3    2023     April   18     1      55
# 4    2023     April   18    15      25
# ..    ...       ...  ...   ...     ...
# 913  2023    August   28    17      36
# 914  2023    August   28    17      38
# 915  2023    August   29     0      39
# 916  2023    August   29     0      46
# 917  2023    August   29     0      51
#
# [918 rows x 9 columns]

# %%
df.shape
# Out:
# (918, 9)

# %%
cleaned_messages = []

for message in df['user_message']:
    cleaned_message = re.sub(r'^\w+\s\w+:\s', '', message)
    cleaned_messages.append(cleaned_message)

df['message'] = cleaned_messages

df
# Out:
#                                           user_message        message_date  \
# 0                 Group creator created group "PTDORM" 2022-12-18 13:19:00
# 1                                       You were added 2022-12-18 13:19:00
# 2    Sayeed Hossain: Logo'r sathe theme ta jacce na... 2023-04-18 01:54:00
# 3                Sayeed Hossain: Make it more natural😅 2023-04-18 01:55:00
# 4                          Akash Ghosh: Mese keo asen? 2023-04-18 15:25:00
# ..                                                 ...                 ...
# 913  Ratul: Vai meal debo apnar ajke raat e??@88016... 2023-08-28 17:36:00
# 914                               Prottoy Vai Asl: nah 2023-08-28 17:38:00
# 915  Badhon Vai: https://fb.watch/mIEV565mlr/?mibex... 2023-08-29 00:39:00
# 916                   Prottoy Vai Asl: <Media omitted> 2023-08-29 00:46:00
# 917                   Prottoy Vai Asl: <Media omitted> 2023-08-29 00:51:00
#
#                                                message                user  \
# 0                 Group creator created group "PTDORM"  group_notification
# 1                                       You were added  group_notification
# 2                    Logo'r sathe theme ta jacce na...      Sayeed Hossain
# 3                                Make it more natural😅      Sayeed Hossain
# 4                                       Mese keo asen?         Akash Ghosh
# ..                                                 ...                 ...
# 913  Ratul: Vai meal debo apnar ajke raat e??@88016...               Ratul
# 914                               Prottoy Vai Asl: nah     Prottoy Vai Asl
# 915       https://fb.watch/mIEV565mlr/?mibextid=Nif5oz          Badhon Vai
# 916                   Prottoy Vai Asl: <Media omitted>     Prottoy Vai Asl
# 917                   Prottoy Vai Asl: <Media omitted>     Prottoy Vai Asl
#
#      year     month  day  hour  minute
# 0    2022  December   18    13      19
# 1    2022  December   18    13      19
# 2    2023     April   18     1      54
# 3    2023     April   18     1      55
# 4    2023     April   18    15      25
# ..    ...       ...  ...   ...     ...
# 913  2023    August   28    17      36
# 914  2023    August   28    17      38
# 915  2023    August   29     0      39
# 916  2023    August   29     0      46
# 917  2023    August   29     0      51
#
# [918 rows x 9 columns]

# %%
users = []
for message in df["user_message"]:
    match = re.match(r'^(.*?):', message)
    if match:
        user = match.group(1)
        users.append(user)
    else:
        user = "group_notification"
        users.append(user)

df['user'] = users

# df.drop(columns={'user_message'})


from datetime import datetime
df['message_date'] = pd.to_datetime(df['message_date'], format='%d/%m/%Y, %I:%M %p')
df['year'] = df['message_date'].dt.year
df['message_date'] = pd.to_datetime(df['message_date'], format='%d/%m/%Y, %I:%M %p')
df['month'] = df['message_date'].dt.month_name()
df['day'] = df['message_date'].dt.day
df['hour'] = df['message_date'].dt.hour
df['minute'] = df['message_date'].dt.minute

# %%
x = df['user'].value_counts().head()

name = x.index
count = x.values
import matplotlib.pyplot as plt
plt.bar(name,count)
plt.xticks(rotation = "vertical")
plt.show()

# %%
round((df['user'].value_counts().head()/df.shape[0])*100,2)
# Out:
# Prottoy Vai Asl    31.05
# Akash Ghosh        16.45
# Rana               12.53
# Sayeed Hossain     12.20
# Asifur Fd           7.73
# Name: user, dtype: float64

# %%
round((df['user'].value_counts().head()/df.shape[0])*100,2).reset_index().rename(columns={'index':'name','user':'percentage'})
# Out:
#               name  percentage
# 0  Prottoy Vai Asl       31.05
# 1      Akash Ghosh       16.45
# 2             Rana       12.53
# 3   Sayeed Hossain       12.20
# 4        Asifur Fd        7.73

# %%
df
# Out:
#                                           user_message        message_date  \
# 0                 Group creator created group "PTDORM" 2022-12-18 13:19:00
# 1                                       You were added 2022-12-18 13:19:00
# 2    Sayeed Hossain: Logo'r sathe theme ta jacce na... 2023-04-18 01:54:00
# 3                Sayeed Hossain: Make it more natural😅 2023-04-18 01:55:00
# 4                          Akash Ghosh: Mese keo asen? 2023-04-18 15:25:00
# ..                                                 ...                 ...
# 913  Ratul: Vai meal debo apnar ajke raat e??@88016... 2023-08-28 17:36:00
# 914                               Prottoy Vai Asl: nah 2023-08-28 17:38:00
# 915  Badhon Vai: https://fb.watch/mIEV565mlr/?mibex... 2023-08-29 00:39:00
# 916                   Prottoy Vai Asl: <Media omitted> 2023-08-29 00:46:00
# 917                   Prottoy Vai Asl: <Media omitted> 2023-08-29 00:51:00
#
#                                                message                user  \
# 0                 Group creator created group "PTDORM"  group_notification
# 1                                       You were added  group_notification
# 2                    Logo'r sathe theme ta jacce na...      Sayeed Hossain
# 3                                Make it more natural😅      Sayeed Hossain
# 4                                       Mese keo asen?         Akash Ghosh
# ..                                                 ...                 ...
# 913  Ratul: Vai meal debo apnar ajke raat e??@88016...               Ratul
# 914                               Prottoy Vai Asl: nah     Prottoy Vai Asl
# 915       https://fb.watch/mIEV565mlr/?mibextid=Nif5oz          Badhon Vai
# 916                   Prottoy Vai Asl: <Media omitted>     Prottoy Vai Asl
# 917                   Prottoy Vai Asl: <Media omitted>     Prottoy Vai Asl
#
#      year     month  day  hour  minute
# 0    2022  December   18    13      19
# 1    2022  December   18    13      19
# 2    2023     April   18     1      54
# 3    2023     April   18     1      55
# 4    2023     April   18    15      25
# ..    ...       ...  ...   ...     ...
# 913  2023    August   28    17      36
# 914  2023    August   28    17      38
# 915  2023    August   29     0      39
# 916  2023    August   29     0      46
# 917  2023    August   29     0      51
#
# [918 rows x 9 columns]

# %%
for message in df['message']:
    print(message)
# Out:
# Group creator created group "PTDORM"
# You were added
# Logo'r sathe theme ta jacce na...
# Make it more natural😅
# Mese keo asen?
# Aci k
# Ami 24 tarike rate ber hbo cabi kar kase thakbe?
# চাবি মালিকের বাসায় দিয়ে গেলে ভালো হয়
# Deao ase....l
# Rana: Good
# Prottoy Vai Asl: @8801733923764
# Prottoy Vai Asl: chol baire ghuira ashi
# Colen vai...tk nai kintu....🙏🙏
# Prottoy Vai Asl: 😒
# Rana: @8801733923764 cholo baire theke ghure asi
# @8801733923764 col cigar khai
# @8801785871932 @8801960629911 @8801682508906 ready hon...🐸
# <Media omitted>
# Including vaiya😥
# Rana: I need a GTR
# Prottoy Vai Asl: <Media omitted>
# Rana: Miss you vai
# Protu kaka
# Prottoy Vai Asl: apatoto shirt kinlam
# Biye naki vai
# ?
# Rana: Serai. Shirt ar gari temon kuno difference nai
# Rana: Jemne takaisen. Monekotsi chosma kinsen
# Cng your shoe
# Looks pocha
# Rana: Iron your shirt
# Iron your pant
# Prottoy Vai Asl: yes ues
# no problem ami ar apnii ekh sathe kinbo ne🙂
# 😅😅
# 😅
# Prottoy Vai Asl: trial ditasilam
# Prottoy Vai Asl: battamiz
# U r
# Mirror selfie kivabe tultu hoi.. Jante hole amk amr inbox e knock koro broo
# <Media omitted>
# 🤟
# Rana akjoner de dekh
# Rana: Kar
# Jar dekhar kotha
# Rana: Kar nam ko
# @8801823182857 jane ami jani na
# kii..??
# Rana: Ami unfollow maira disi
# Rana: Moner osanti baraite chai na
# ki bolteco vii kicu bujteci na
# Rana: Mourin er day dekhte boltese amare
# Moner osanti to akhanei bere gelo tor
# Cigar koyta ase?
# ore bol oy dekhte
# 😅😅
# Rana: Next topic
# Rana tumi tension korio na...ami ese tmk ekhta treat dibo
# tor pice diye vore dibo sala..
# Rana: Gracias
# ?
# Rana: Gracias means thanks, i am delighted
# okay 🙂
# <Media omitted>
# who is he😅😅
# Tui chele ki meye vorti korsis janis na abar he r she dekhtesis
# Gd job...
# eta koi jon pare...tuii parle kore dekha
# Boro vai ra na thakle bltam toke
# Rana: Shahin dhore fel
# Tuii ar ki bolbi bokupaga 😅😅
# Prottoy Vai Asl: <Media omitted>
# mistake..
# Ratul: But vaai apni ektu vul bollen..Hossain to already e ekta She🥲..She needs a He like Akash!
# tmk niye kicu bolbo ki ratul
# viral kore dibo kintu
# roja ta ses hok..then
# Sobai k eid mubarak.
# R eid er salami ta diyen amak 🙂
# Prottoy Vai Asl: <Media omitted>
# Prottoy Vai Asl: salami
# Prottoy Vai Asl: <Media omitted>
# Rana: Ki eida
# Prottoy Vai Asl: <Media omitted>
# Prottoy Vai Asl: ice cream
# Prottoy Vai Asl: <Media omitted>
# Price to jani na but Movenpick ekhta fancy Ice-cream corner ace Gulshan e...
# and all flavour er Ice-cream pawya jaii
# And onk costly 🥺
# And it's brand bro..
# Rana: Around 600 taka
# hm Emon e
# but eter price aro kom hobe
# Rana: 300
# Hm emon hobe hoi to
# Eid kar kmn katlo
# @8801682508906 vai thik ase to sob.
# amr besi valo na...kono picture tulii naii
# Usa asle couple tulis
# and eid er picture o upload korte parlam na🥺
# baaaaaLLL er jibon
# salar ajk sara din room e katailam
# Ballll
# Biye 2ta korbo 1ta USA and ekhta Mymensingh 😊😊
# Mymensingh koris na
# Keo keo boltece to Mymensingh er manush bole onk valo
# So try kore dekhii😅
# Kor pore ranar mto obostha hbe tor
# ranar abr ki hoice..
# Or kase son
# oy to buk fate to mukh fate na😅
# ki hoice bol
# Buk e fatbe tor o tai bollam
# ki hoice sala ota bolleh e to hoi
# @8801682508906 vaii eid er salami to dilen naaaa
# Prottoy Vai Asl: hoy nai
# @@8801960629911
# ?
# আমি কল দিচ্ছি
# Ok
# Rana: Ok
# কাল কল দিই, রাত হয়ে গেছে
# You deleted this message
# Porsu k k astesen
# Ami porsu sokale pouchabo
# Ratul: Ami 25 tarikh dupure pouchabo
# Prottoy Vai Asl: koyta
# Prottoy Vai Asl: @8801733923764  @8801785871932  @8801960629911
# Rana: Ami dekhi kal , porsu
# Ami porsu...
# Rana: @8801785871932 aisos?
# Ha
# Rana: Ami bikaler dike asbo
# Ok
# Ratul: Ami aschi..akhn bus e uthbo
# tmra soby asar por ami asbo..
# Amar 450 tk r vara na ki 1300 tk... Ami jabo na...ar...
# Vai ratul 1000 disse wifi bill
# Bill diye kon number a phone dite hbe
# Line calu korar jnno?
# Prottoy Vai Asl: shahabuddin re call de
# mess e ke ke present acoc
# Ami rana ratul
# gd
# Rana: @8801741525387 link koi
# Ratul: This message was deleted
# Prottoy Vai Asl: <Media omitted>
# Rana: Enjoy your meal ❤️
# Rana: Kobe asben vai?
# Prottoy Vai Asl: <Media omitted>
# Prottoy Vai Asl: Saturday
# Rana: Joss
# 😥
# https://www.facebook.com/reel/254102250333759/
# <Media omitted>
# Ekta insurance company r application er moto  jekhane onk gula insurance company r nam thakbe user problem e porle tar register kora insurance e click korbe and help chaibe , then ambulance/ towcar availability r upor driver select korbe victim er location e asbe
# Aro besh kichu requirements ase
# Ekram bhai amr porichito Apni payment niye kono chinta koiren na 😅
# Prottoy Vai Asl: Ki aita ?
# @8801682508906
# vai dekhen
# project
# ekram vai arekta jogar kore dise
# baire thake
# ager tar mto
# Prottoy Vai Asl: Deadline ?
# Prottoy Vai Asl: Me kaj
# robibar
# first submission
# Prottoy Vai Asl: Flutter a kora lagbe !!!
# 4 ta phase ase
# ha
# Prottoy Vai Asl: 3 din a !!
# Prottoy Vai Asl: Tora available ??
# ha
# Prottoy Vai Asl: Total app 3 din a !!
# na
# Prottoy Vai Asl: To ?
# 4 ta date ase
# robibar 1st submission
# hoyto olpo kisu korte hbe
# Prottoy Vai Asl: Payment koto total ?
# ami blsi rate knk dissi
# bli ni kisu
# ..
# Prottoy Vai Asl: Ui bana no ase?
# na
# Prottoy Vai Asl: 20 k
# Prottoy Vai Asl: Total app
# Prottoy Vai Asl: Ko
# Prottoy Vai Asl: Raji thakle shuru kormu
# Prottoy Vai Asl: Raat a
# suni ui dibe kina
# r robibar kototuku dite hbe
# Prottoy Vai Asl: Hmm
# Prottoy Vai Asl: Ar advance payment
# Prottoy Vai Asl: Must
# Feature dekhsen vai?
# Etao Malaysia meye may be
# Prottoy Vai Asl: Dekhlam
# Design ta dile valo hoto
# R location diye kaj kora lagbe
# Geo locator package ase but kaj ta khub easy na
# Ambulance /Towcar er feature ta
# Prottoy Vai Asl: 25 k
# Taka pore kam ta korte parle amader o lav
# Grp a koyjon dekhi
# Tarpor mathapichu 5k😀
# Prottoy Vai Asl: Taka chara Ekhon motivation parmu na
# 😀
# Prottoy Vai Asl: 10 k
# Takay taka😀
# Kam sesh kora lagbo to
# Asen shuru kori eta
# Moja ase project tay
# Prottoy Vai Asl: Payment fix koro
# Prottoy Vai Asl: Then
# Hmm
# Ager project ta ki successfully disen vai?
# Prottoy Vai Asl: Hmmm
# Prottoy Vai Asl: Disilam e to
# Ok.etao vau kortesi
# Asben kbe?
# Prottoy Vai Asl: Ami Ekhon e e kaj shuru korte parmu
# Prottoy Vai Asl: Saturday
# Shuru koren authentication
# You deleted this message
# Authentication to lage
# J app e hok
# Ami e-commerce tar akta design a atke asi
# Prottoy Vai Asl: @8801960629911
# Prottoy Vai Asl: Ki
# Prottoy Vai Asl: Ase
# Ha
# Prottoy Vai Asl: Amar meal dis
# Prottoy Vai Asl: @8801733923764
# Prottoy Vai Asl: Aisos ??
# Vai nai ami....
# @maneger amar ar @8801682508906 ar meal dio...
# Prottoy Vai Asl: Tui ashtasish?
# @8801682508906 ভাই আমি বাসে, এসেই সব ক্লিন করে নিব নে।
# https://youtu.be/kKx-yLtrT1A
# Ratul: https://youtu.be/k82YJE0ww-g
# amr ajk rater meal hobe
# Prottoy Vai Asl: Oka
# https://youtu.be/TWRKrL0ti9k
# Ratul: https://youtu.be/2Hj5X6RnYi4
# Prottoy Vai Asl: amar meal cholbe na
# Prottoy Vai Asl: shokal a
# Prottoy Vai Asl: <Media omitted>
# Prottoy Vai Asl: <Media omitted>
# Prottoy Vai Asl: teka deeeeeeeeeeeeeeee
# Prottoy Vai Asl: polapain
# Prottoy Vai Asl: i'm fokir right no w
# Prottoy Vai Asl: <Media omitted>
# Kal dupure dal r alu vaji
# BaaLLLLLL
# Jdi শুটকি  thake tahole alu vajir jaigay শুটকি।
# শুটকি না থাকলে পরে ডিম এনে ভেজে নিব।
# Sutkii hole amr meal off
# মিল লিয়ান ভাই এর টা না চললে ৭ টা
# sokale uthe sune off kris.Sutki ase kina jana nai amar.
# Rana: <Media omitted>
# Rana: <Media omitted>
# Rana: <Media omitted>
# Rana: <Media omitted>
# Rana: <Media omitted>
# Rana: <Media omitted>
# Rana: <Media omitted>
# Rana: <Media omitted>
# Rana: <Media omitted>
# Rana: <Media omitted>
# Rana: <Media omitted>
# Rana: @8801733923764
# Akhane ki keo cigar fuksilo?
# Prottoy Vai Asl: Chabi
# Prottoy Vai Asl: Gate er shamne Kalo ponce er niche
# https://youtu.be/SXb5VfwcmK0
# Prottoy Vai Asl: https://youtu.be/vKudQsZMosU
# Prottoy Vai Asl: Current arse re?
# Prottoy Vai Asl: Wi-Fi thik hoise ????
# Prottoy Vai Asl started a call
# Rana: Vai , amra class e
# Na
# Prottoy Vai Asl: Call deeeeeeee
# Number nai
# Current cole gese
# Prottoy Vai Asl: Ciger kinsi
# Sobi den ami biswas kori na
# Prottoy Vai Asl: <Media omitted>
# Gd
# Asta
# Astasi
# Ratul: গাঞ্জা নাকি?😢
# Koi vai apni asen bose asi
# Prottoy Vai Asl started a call
# HI, USE THIS CODE: FC835DD35FCEE937@FR.RC TO ADD ME TO YOUR FRIEND LIST IN REAL CRICKET 22!
# Prottoy Vai Asl: korlam na add
# Prottoy Vai Asl: 😒
# Rana: 😆
# Prottoy Vai Asl started a call
# Kal sokale meal colbe
# Kar kar colbe janan
# Prottoy Vai Asl: Current aise?
# Na
# Asce vaii
# matro aslo
# Prottoy Vai Asl: <Media omitted>
# Prottoy Vai Asl: This message was deleted
# Prottoy Vai Asl: This message was deleted
# Rana: 😆
# Rana: Congratulations
# Ccc vai agula manus kore??? 🐸
# Prottoy Vai Asl: 😑
# Prottoy Vai Asl: tui amare omanush koili !!
# Rana: Ami ektu Omanush hoite chai 😒
# Vai agula onno level ar manus kore apni to  vai manus ar upore...🐸🐸🐸
# Prottoy Vai Asl: naaaaaaaaaaaaah
# Vai tik cilen???
# Na ki pet teke sob ber kore dicilen???
# Prottoy Vai Asl: nah
# Rana: Vai koi achen. Khuda lagse. Na kheye class kortesi vai. Jodi khudartho chuto vaider mukhe kichu onno tule diten onek khushi hoitam
# Prottoy Vai Asl: 2 ghonta er moto dunia ultay poira chilam
# Prottoy Vai Asl: then all ok
# Prottoy Vai Asl: mara khau
# Joint kaicilen na ki??
# Prottoy Vai Asl: hoo
# Vai apni to asolaee onno level ar... Mante hosse vai...
# Rana: Police re phone ditasi kharan
# @sahab vai dorja ta bondo kore den...
# Prottoy Vai Asl: amar meal on
# Prottoy Vai Asl: dupur theke
# Rana: <Media omitted>
# Prottoy Vai Asl started a call
# Md Shahab Uddin: @8801823182857 amar aj rat & kal dupure meal off.
# Prottoy Vai Asl left
# https://youtu.be/qwnw91l3WFk
# Amr mouse?
# Curret asse?
# Rana: Na
# Rana: Matro aslo
# Kal amr mil on
# 2 ta.
# Dupur plus rat
# <Media omitted>
# <Media omitted>
# Can i post?
# With valuable caption?
# Ratul: @8801823182857
# My dear roommates flatmates keo kindly juta niye baire jaiben na.
# @8801305943612 vai misbah re grp a add diye diyen
# Amr kase or number nai
# https://youtu.be/UpQcLFnMCQY
# Vat nai rater
# Akta dim nilam
# Md Shahab Uddin: Ok
# Md Shahab Uddin: @8801785871932 @8801322451017 @8801741525387 @8801733923764 Meal e taka porjapto porimane nai kal bari bara dite hobe. Sobai kal taka diben...
# আমি ত আপনাকে 2500 দিয়েছি
# আর 500 আমি দিব নি
# গিয়ে বাসায়।
# Ratul: Vai kalke to dite parbo na..2/3 din somoy laagbe..ar akhn apatoto hoito highest 500 dite parbo vai..
# Md Shahab Uddin: 2500 + 500 diye jodi hoy tahole valo kotha tobe ta howar noy
# 3000 dicchi
# Md Shahab Uddin: Kobe
# Jodi pore amr ro deuya lage pore dibo ekhn amr kache nai.
# Ami total 3k
# Md Shahab Uddin: Na
# Md Shahab Uddin: 2500
# Dicchi kal 500
# Kal 5 diye 3k puron kortechi.
# Md Shahab Uddin: Ok
# https://youtu.be/wYcCBD3q-NY
# https://youtu.be/bj2hStJ8t1M
# Ratul: https://youtu.be/Wm7kaTURU9M
# <Media omitted>
# Reaction.. 😅😅
# Rana: 😆
# You deleted this message
# @8801823182857 rag krsis naki
# Ptdorm a disos kn
# Low t te dibi ta
# Sorry*100
# চরি
# Rana: Anonde kede felbo
# O mne hoy dekhe ni ki likhsi
# Rana: Akash tor ki khobor
# Rana: Kuno sara sobdo pai na
# Akash thanda hoye gese
# Rana: Barite asos na Lal dalane
# Rana: Ki emon ghotlo
# Rana: Je thanda hoye geli
# Lal dalan koi abar
# Rana: Mamar bari. Police station
# মরে মরে বেছে আছে
# Boka....
# So
# Sob
# Vag
# Rana: Je bole se hoy
# Rana: 😑
# btw guys advance Eid Mubarak
# Rana: Eid Mubarak ❤️
# 01785871932
# @everyone
# Rana: Number sora
# Bkash personal
# Rana: Kurbanir eid e salami chay na kew
# kicu bollam na
# Sobai nisse j
# Day disse
# Asif 500 dise
# Zinia re
# <Media omitted>
# <Media omitted>
# Rana: 😑
# Rana: Ora premik premika
# Rana: Koto nise
# Ei zinia ta abe keda
# 200000tk
# Ranar khabar asif kheye nise
# 😅
# kon khabar
# Rana: Valo hoise. Anader ekhane etar dam 2.5 hoito
# accah
# Magi noodles
# Ebar...emne teii cow er piece onk besi
# Rana: Akash tore mair deya uchit
# O accah😅
# This message was deleted
# Chill mood aci guys
# Rana: Ho Chill e thako. Matha gorom koirona
# 😅😅...hm
# You added Prottoy Vai Asl
# Prottoy Vai Asl: <Media omitted>
# Prottoy Vai Asl: @8801785871932  @8801960629911
# Prottoy Vai Asl: kar kase
# Prottoy Vai Asl: ase
# Prottoy Vai Asl: dekh to
# Prottoy Vai Asl: group a deya  chilo may be
# Rana: Amar ekhan theke tutora log out hoye gese.
# Prottoy Vai Asl: tutora er email a chilko ?
# Rana: <Media omitted>
# Rana: Eita ki
# Rana: @8801682508906
# Prottoy Vai Asl: nah
# Prottoy Vai Asl: aita na
# Prottoy Vai Asl: hmm
# Prottoy Vai Asl: aita diya cholbo
# K kobe astesen?
# Ami porsu sokale pouchabo
# Kal rate bus
# Prottoy Vai Asl: <Media omitted>
# Rana started a call
# Prottoy Vai Asl: <Media omitted>
# Prottoy Vai Asl: <Media omitted>
# Rana: Good
# Prottoy Vai Asl: google play account
# Prottoy Vai Asl: ban khay naki
# Prottoy Vai Asl: ektu check dis to
# Prottoy Vai Asl: ami account vara disi
# Prottoy Vai Asl: kintu i'm doubtful
# Prottoy Vai Asl: Amar raat a meal dis
# Prottoy Vai Asl: @8801741525387
# Prottoy Vai Asl: tui kobe gesos re ???
# Prottoy Vai Asl: @8801733923764
# Prottoy Vai Asl: tui koto disi re ]
# Prottoy Vai Asl: Eid er age ???
# Prottoy Vai Asl: 500 na ?
# Prottoy Vai Asl: @8801733923764 103 taka dibi
# @manager
# Prottoy Vai Asl: @8801733923764  @8801960629911
# Prottoy Vai Asl: apnader
# Prottoy Vai Asl: meal poira ase
# Prottoy Vai Asl: apnara koi ?
# Rana: On the way
# Prottoy Vai Asl: https://www.youtube.com/watch?v=4aWLA5GHEOU&ab_channel=DJIDE%3ATV
# Rana: https://www.facebook.com/reel/1146504642931431?mibextid=fazHQh&s=yWDuG2&fs=e
# https://youtu.be/5S1UrSwv5m8
# Prottoy Vai Asl: bacchara
# Prottoy Vai Asl: basha cara deua lagbe
# Prottoy Vai Asl: teka jogar koro
# Keno
# Vai
# ?
# R kobe chara lagbe vai?
# Prottoy Vai Asl: basha vara deua lagbo
# Prottoy Vai Asl: =_=
# Prottoy Vai Asl: @8801785871932
# Prottoy Vai Asl: Meal thikka taka nia
# Prottoy Vai Asl: Dim nia ay
# Taka kothay
# R koyta anbo
# Prottoy Vai Asl: 24ta
# Prottoy Vai Asl: Amar table a choshma’r box a
# Accha vai..
# 😌
# Prottoy Vai Asl: @8801741525387  @8801322451017  @8801305943612
# Prottoy Vai Asl: teka pathaaaaaaaaaaaaaaaaaaaaaa
# Prottoy Vai Asl: 2 koira
# Prottoy Vai Asl: vara deua lagbo kal
# Prottoy Vai Asl: meal a 4k ase
# Ami ashtechi aj india thaika kal basay thakbo.  Amr meal diyen dupur plus rat er ta.
# Ratul: Kal jabo vai.. Giye dissi
# Prottoy Vai Asl: 2k koira dite hoibo
# Prottoy Vai Asl: <Media omitted>
# Prottoy Vai Asl: total 13300 lagbo
# Ratul: Kal dupur e amar meal hobe...
# Prottoy Vai Asl: <Media omitted>
# Prottoy Vai Asl: vaia ra
# Prottoy Vai Asl: taka dia jau
# Prottoy Vai Asl: amar kase
# Prottoy Vai Asl: vara dia ashmu
# Prottoy Vai Asl: @8801733923764  @8801322451017  @8801741525387
# https://youtu.be/waDXMSI4KLo
# Prottoy Vai Asl: <Media omitted>
# Prottoy Vai Asl: taka felau polapain
# Prottoy Vai Asl: https://www.youtube.com/watch?v=zDQKb-3wtLg&list=PLV5nEXgC3EXYqd2DbCFXjDdI7sVGs18wD&ab_channel=AHaunting
# Prottoy Vai Asl: <Media omitted>
# Ratul: Bhai yeh to kala jaadu hai
# Prottoy Vai Asl: <Media omitted>
# Amr
# Rate ekta mill diyen
# Kal amr 2.5 mil vai.
# Prottoy Vai Asl: <Media omitted>
# Prottoy Vai Asl: @8801823182857  @8801741525387
# Prottoy Vai Asl: Shukna bazar kor Ekhon
# Prottoy Vai Asl: Ja
# Prottoy Vai Asl: Onto kintu Kal o meal off rakhmu
# Prottoy Vai Asl: Dim anis shathe
# Prottoy Vai Asl started a call
# Prottoy Vai Asl: Raat a Amar meal baad a gune meal dis
# Amr meal colbe dupure r  rate 2 ta
# https://youtu.be/ly3LNBbRFXg
# Rate amr ekta mill colbe.
# Prottoy Vai Asl: <Media omitted>
# Cabi
# Ker kache
# ?
# Prottoy Vai Asl: Shamne r dokan a
# Badhon Vai started a call
# Next month theke amr meal off
# Ami r meal calabo na
# Bua meal dibo na.establish ja ase segula dibo jmn basa vara current bill wifi bill...
# Prottoy Vai Asl: asho
# Prottoy Vai Asl: ajk kichu rules deua lagbo
# Koi amu
# Prottoy Vai Asl: ami ashar age keu
# Prottoy Vai Asl: torkari te haat dibi na
# Prottoy Vai Asl: haat dile 5 meal jorimana
# Sokale kar kar mill colbe?
# R dupure r rate
# Md Shahab Uddin: Amar sokal + dupur
# Rana: Sokal bikal rat
# Bakira
# Bolen
# Prottoy Vai Asl: 3 bela
# Asif 3 bela
# Hossain
# 3 bela
# Prottoy Vai Asl: <Media omitted>
# Md Shahab Uddin: <Media omitted>
# Mill
# Bolo
# Ker koita?
# Md Shahab Uddin: Amar sokal o dupur
# Sobai bolo
# 2.5
# R baki sober same mil rakhlam
# Jodi change kora lage tahle rate janaba
# Nah hoi eitai confirm
# Change hoile rate amr room e bola lagbe aysha
# Kal sokale mill colbe 7 ta.  Prottoy vai apu k bole diyen.
# Mill sikale kal vat half dim and dal.
# Dal, vat r half dim vaji.
# Rana: 2.5
# .
# 2.5
# Prottoy Vai Asl: 2.5
# Ratul: Dupur Theke  amar meal diyen
# Ami sokaler meal pai n
# Ni
# K khaise jani na
# @8801322451017
# Vai
# Paisi vai but dal nai.Next din theke aktu kheyal raikhen ja den na kno sesh porjnto jno thake.drkr hoy alada patro kenen establish theke.Ami regular seshe khai akhon.next din theke dal thakuk jai thakuk amr jnno na thakle meal tulben na.
# Okkk choto vai akash
# This message was deleted
# This message was deleted
# Md Shahab Uddin: @everyone
# 2.5
# Prottoy Vai Asl: 2.5
# Rana: 2.5
# 2.5
# Ratul: ২.৫
# Md Shahab Uddin: @everyone
# Rana: 2.5
# 2.5
# 2.5
# Ratul: 2.5
# Md Shahab Uddin: @everyone
# Prottoy Vai Asl: 2.5
# Amr 2 ta
# Rana: 2.5
# 2.0
# klk amr 2.0
# sobai  mill bolo
# Md Shahab Uddin: 1.5
# Rana: 2.5
# 2.5
# Ratul: 2.5
# Md Shahab Uddin: kal amar meal 1.5
# Baki sobay bolo
# Rana: 2.5
# Klk amr 2.0
# not 2.5
# Ratul: 2.5
# Prottoy Vai Asl: 2.5
# Prottoy Vai Asl: amare raat 2.30 a ghum thikka tuilla dis
# Jader jader taka daw ni
# Tara Kal taka diba basa vara dauya lagbo
# Kal
# 2.0
# Rana: 2.5
# 2.0
# Prottoy Vai Asl started a call
# Prottoy Vai Asl started a call
# Md Shahab Uddin: https://youtu.be/fHqMjWNirns
# Prottoy Vai Asl: apu ashbe
# Prottoy Vai Asl: akash re murgi ante pathais
# Prottoy Vai Asl: shsthe ja ja lage
# Kal amr mil colbe dupur plus rat 2 ta r amr friend j chilo oi sob mil amar khane tule diyen
# Kal amr mill 2ta
# Dupur +rat
# Ratul: kal Amar
# Ratul: This message was deleted
# Ratul: This message was deleted
# Ratul: 2.5 hobe
# Ratul: Sokal theke...
# Ratul: Shuru
# Vai aj ke amar 1 meal colse....
# Kal ke amar 2.0
# Badon vai ar 2.0
# Rana: Ajke 0 , kalke 2
# Ratul: This message was deleted
# vai amaro taile 0.
# @8801682508906 bhai amr 13 tarikh rater meal chilo na..I means apni 6ta meal dichilen but public chilo 7 jon..so, rate ami meal pai ni
# Ratul: Ajke amar 2 meal cholse
# @8801682508906  vai ami 500 tk dici...
# Prottoy Vai Asl: shokal a bajar a jabi
# Prottoy Vai Asl: ajk?
# Hmm..
# Ajk amar 2 mill colse r kal amr 2 mill colbe.
# Ratul: @8801823182857
# Ratul: পেয়াজ -২ কেজি
# Md Shahab Uddin: 14/08/23
# Prottoy Vai Asl: kalk r meal likh
# Prottoy Vai Asl: shobai
# Prottoy Vai Asl: 2.5 koira dia dimu noto
# Ratul: আমার ২ মিল কালকে।
# Md Shahab Uddin: 14/08/23
# Prottoy Vai Asl: @8801785871932
# Prottoy Vai Asl: @8801960629911
# 0
# Rana: 2
# Prottoy Vai Asl: ajk taka disos k k?
# Ami 500 dici...
# Rana: Ami 500 current bil
# Prottoy Vai Asl: kal dupur a 6 ta meal ranna korte bolbi ,
# Prottoy Vai Asl: shokal a nai
# Prottoy Vai Asl: @8801823182857  bajar korbi shokal a
# Prottoy Vai Asl: ar apu re boilla dibi
# Ratul: আজকের বাজার ৬৩৮ টাকা
# Prottoy Vai Asl: kal kar meal koyta
# Prottoy Vai Asl: likkha de
# Rana: 2
# 2
# Amr 2
# Ratul: 2
# Prottoy Vai Asl: @8801733923764 ?
# 2.0
# Prottoy Vai Asl: raat a ki ranna korse ajk?
# Rana: Khichuri with murgi chilo
# Rana: Eksathe mix
# Prottoy Vai Asl: 😒
# Rana: Like dry khichuri
# Rana: With jhuri jhuri chicken
# Prottoy Vai Asl: meal a taka disos @8801741525387
# Ratul: Na vai. Apatoto lagbe na..kal cashout kore debone!! Kalker bajar hoye gese
# Prottoy Vai Asl: apu'r beton baki
# Prottoy Vai Asl: 3k
# Prottoy Vai Asl: 😒
# Rana: K K K
# Prottoy Vai Asl: kal dupur a 6 ta meal , raat a 5 ta
# Apu tk caice vai....@8801682508906
# Prottoy Vai Asl: greattttttt
# Rana: Ami 1 hazar dimu ne
# Prottoy Vai Asl: @8801741525387
# Ratul: Ji vai amio 1500 moto debone
# Kal thaika amr mill off
# Md Shahab Uddin: Amar 1 ta
# Prottoy Vai Asl: meal likh
# Prottoy Vai Asl: shobai
# Ratul: 2.5
# Rana: 2
# Prottoy Vai Asl: kal dupur a 3meal
# Prottoy Vai Asl: taile?
# Prottoy Vai Asl: @8801733923764  @8801823182857
# Prottoy Vai Asl: @8801785871932  2ta re
# Prottoy Vai Asl: ekta koira latthi de to
# 2
# Prottoy Vai Asl: asif re de
# Disi
# 2.5
# Rana: Vai sokale tahole 2.5
# Rana: Exam ache
# sm
# Prottoy Vai Asl: shokal a 4 ta
# Prottoy Vai Asl: shokal a dim thakle dim r khichuri , na thakle vaat daal aluvorta
# Prottoy Vai Asl: @8801741525387  ja
# Prottoy Vai Asl: @8801785871932  latthi mar to
# Amr kono mill colbe nah vai
# @8801682508906 vai apni kobe asben??
# Prottoy Vai Asl: no idea
# Prottoy Vai Asl: ammu shustho hour por
# Oh..assa
# Vai apu koto tk pabe??
# Prottoy Vai Asl: apu re 3000 de
# Prottoy Vai Asl: ko j 300 nai
# Rana: Vai ami 1000 disi. Amar total 4500 hoise
# Prottoy Vai Asl: ok
# Ar samne mas teke boli je apu amar 4 jon kabo apnake 2k dibo apni ki takben??? Apni jodi kan taile 5 jon??? 🐸🐸🐸
# Prottoy Vai Asl: ko j ek bela aisha ranna koira dia jaba
# Prottoy Vai Asl: amar thaka hoile o max 10 din
# Ok
# Ratul: vai ami 1000 joma disi...apu r Beton er vetor.
# Prottoy Vai Asl: tui na 1500 dibi
# Prottoy Vai Asl: tor aro taka lagbo
# Prottoy Vai Asl: taka de
# Ratul: Ji vai..amar ageee 1500 dewa chilo..ar ajke 1000 dilam...ar 1000/1500 debo shonibar e..
# Amr mill 0.  Kal o.
# Amr kal o kono mill colbe nah. Mill off thakbe.
# Ratul: <Media omitted>
# Ratul: <Media omitted>
# 2.0...
# Rana: 2
# Ratul: Kal 2 meal amar
# Ratul: 2
# Jodio meal a kisu nai...tk oo nai...🐸🐸🐸
# Prottoy Vai Asl: meal ar taka shesh?
# Prottoy Vai Asl: Apu re koto disos?
# Ratul: 3000
# Ratul: Hae vai
# Ratul: Ami 200 dite parbo apatoto..ar 1000  kal ba porsu debo
# Md Shahab Uddin: Amar kalk 1 meal colbe
# Prottoy Vai Asl: deu
# Prottoy Vai Asl: kal dupur a dim vuna korau
# klk 2.0
# Prottoy Vai Asl: dupur a 5 ta
# Prottoy Vai Asl: meal
# Prottoy Vai Asl: dupur a dim vuna
# Prottoy Vai Asl: daal 2 bela e
# Prottoy Vai Asl: meal nai ?
# 2.0
# Rana: ২
# Ratul: ২
# amr 0 mill
# Prottoy Vai Asl: taka disos k?
# Prottoy Vai Asl: ranaa korar ki ase ?
# Kal sokal a bajar korbe ratul...
# Tk nai...o tk dibe and bajar korbe..
# ২
# Md Shahab Uddin: Amar 1 ta
# Ratul: মুরগি
# Md Shahab Uddin: Kal amar 1 ta meal
# Rana: 2.5
# 2.5
# 0 mill amr
# klk amr 2.5
# Ratul: 2.5
# Prottoy Vai Asl: shokal a 5 ta
# vai ajk amr 1 mill only dupur er
# Vai aj amaro only 1 meal colse...
# Ar ami 500 tk dici meal a...
# Amar meal akn teke off
# amr o same ajk theke off only ajk 1ta meal cholce
# Prottoy Vai Asl: tora bari jas?
# Hmm
# Prottoy Vai Asl: ashbi kobw?
# Ami 4/5 din por asbo...
# vai asbo 7 week por
# Prottoy Vai Asl: 7 week 🥴
# Prottoy Vai Asl: 49 din por
# Prottoy Vai Asl: ki kos
# 😅....na vai 1 week hobe
# Besi excitement e pore gechilam to.. tai ar ki bole dici😅😅
# Prottoy Vai Asl: KI PORE GESE ?
# Prottoy Vai Asl: ou
# Prottoy Vai Asl: 😅
# 😅😅...
# Prottoy Vai Asl: This message was deleted
# Prottoy Vai Asl: 🥴
# Ratul: @8801682508906 vai ajke meal er hisab close kore felen
# Prottoy Vai Asl: ok
# Ratul: Ami eka meal chalacchi..apu asbe..ranna kore dibe ei month..Taka poisa r hisab kore ke koi taka pabe ba dibe meal e seta ektu diye den..tahole subidha hoi...
# Prottoy Vai Asl: ok
# Train charar kotha 08:02 but train bole asbe 10-12 tar moddhe😥
# Rana: Bondhu dhuwa ura
# Enjoy... 🐸🐸
# 😥
# 😥
# train accident korce bole..
# Rana: Asif kobe jaba
# Ami varit aice 2 hour age...
# Rana: Ami bari theke chole jabo. 10 ghonta pore
# Rana: Jodi mon chay
# Rana: 😆
# 🙃🙃
# Rana: Barite ailam , sei santi
# Rana: Khali ghum
# 😥😥🤔...amr ekhon ei obbostha
# Abar room a ay akta benson niye ay
# Tarpor abar jas
# train astece...
# Md Shahab Uddin: Have a good journey 😆😆😆😆
# ei mtro train e utlam..
# Md Shahab Uddin: Station theke sabdane jais
# Md Shahab Uddin: Bag gula sabdane rakhis
# Md Shahab Uddin: Na hoy tor vaire ko asto
# okay bhai problem hobe na ins hallah
# Hasan asbe
# Prottoy Vai Asl: meal a kono taka ase ?
# Prottoy Vai Asl: ami ashar por current bill koto disili ?
# Rana: 500 maybe
# Prottoy Vai Asl: check history
# Prottoy Vai Asl: on nagad
# Rana: 500
# Rana: Last 2 bar 500 kore vorsi
# Prottoy Vai Asl: This message was deleted
# Rana: Sobuj gula ki firot pabo?
# Prottoy Vai Asl: hmm
# Rana: Give me money. I need them badly 😭
# Prottoy Vai Asl: 😒 give me 10k dhar
# Prottoy Vai Asl: then torta ditasi =_=
# Rana: Amare 854 den pore ditesi, karon amar call age chilo
# Prottoy Vai Asl: @8801305943612  mesbah thikka 450 taka nibi
# Prottoy Vai Asl: @8801322451017 80 taka dibi
# Prottoy Vai Asl: ore
# Prottoy Vai Asl: taile @8801305943612  amar kase aro 530 taka pabi
# Prottoy Vai Asl: kat chat koira
# Prottoy Vai Asl: 520 taka pabi @8801741525387
# Ratul: @8801682508906 vai amar kache meal er 675 taka ache..kalke raat e aro 1 haali dim kinsi..akhn ar 675 taka ache..ki korbo eita?
# Ratul: Sorry..675+50=725 taka ache...Akash er theke 50 taka pawa jaabe.
# Prottoy Vai Asl: ekta latti mari ekhon tore =_=
# Ratul: Kn vaii??
# Prottoy Vai Asl: hishab korar por kos taka  ase
# Ratul: Taka to chilo e vai....
# Prottoy Vai Asl: abar kora lagbo =_=
# Prottoy Vai Asl: baaaal
# Ratul: Asif gotokal 350 taka dise
# Prottoy Vai Asl: to edi likhos nai ken group a =_____=
# Ratul: @8801733923764 tomar total koto taka dewa ache??? Hisab bolo
# Ratul: Vai amio janina or hisab ta clearly.. Bujhini ar ki😑
# Ratul: Asif agee boluk vai..tarpor hisaab koren..
# Prottoy Vai Asl: 😒😒😒😒
# Ratul: Esike meal er taka diye ami goto kal.eka meal chalaisi..
# Ratul: Ajkeww ami ar rana khacchi
# Prottoy Vai Asl: 😒
# Ratul: Tahole ki korbo vai???
# Prottoy Vai Asl: tora ki khabi ai mash |?
# Prottoy Vai Asl: ami 28 a aisha khamu
# Prottoy Vai Asl: taile ekhon hishab shesh kormu na
# Ratul: Hae vai.. Ami regular khabo..rana o ache
# Prottoy Vai Asl: badhan koi ?
# Ratul: Hae vai. Tokhon e koiren..
# Ratul: Asenaai
# Amio
# Khamu
# 25 thaika
# Md Shahab Uddin: Ei maser hisab koi
# Prottoy Vai Asl: dltd
# Prottoy Vai Asl: edi bole aro khaibo
# Md Shahab Uddin: Eta kemon kotha hoilo.?
# Prottoy Vai Asl: taka poisha change hobe
# Prottoy Vai Asl: tai
# Prottoy Vai Asl: @8801741525387
# Ratul: Ji vai
# Prottoy Vai Asl: Koyda khas
# Ratul: Thik ache vai
# Ratul: Ajker amar 2 ta meal hoise..rana r 1 ta..
# Prottoy Vai Asl: date shoho likh
# Ratul: ২১-৮-২০২৩
# Prottoy Vai Asl: gooodd
# <Media omitted>
# vai amr rater meal off🐸
# Rana: 😒
# 😥
# Ratul: Bro beaf naki dog? Sultan’s Dine?
# Na sultan's dine na
# Nanna...
# Ratul: ajke 23 tarikh
# Amar mill deish rat e 1 ta ratul
# 25 ---- ratul 2 rana 2 badon vai 1
# vai ami 1000 tk dici..
# ratul 500 tk dise
# asif total 4700tk
# ratul total 4200tk
# Prottoy Vai Asl: onnk khaitasos to tora 🙄
# Prottoy Vai Asl: ami kaal raat 11 tay train a land kormu
# Prottoy Vai Asl: keu station a ashish
# This message was deleted
# Md Shahab Uddin: Sathe jodi vabi vaijta thakto tobe ekta cesta diye dekhtam
# Rana: Okay
# Prottoy Vai Asl: 🤬 bag ase
# Ratul: Vai meal debo apnar ajke raat e??@8801682508906
# Prottoy Vai Asl: nah
# https://fb.watch/mIEV565mlr/?mibextid=Nif5oz
# Prottoy Vai Asl: <Media omitted>
# Prottoy Vai Asl: <Media omitted>

# %%
# import re

# def count_emojis(message):
#     emoji_pattern = r'[\U0001F600-\U0001F64F\U0001F300-\U0001F5FF\U0001F680-\U0001F6FF\U0001F700-\U0001F77F\U0001F780-\U0001F7FF\U0001F800-\U0001F8FF\U0001F900-\U0001F9FF\U0001FA00-\U0001FA6F\U0001FA70-\U0001FAFF]'
#     emojis = re.findall(emoji_pattern, message)
#     return emojis

# # Example messages
# df = pd.DataFrame({'message': df['message']})

# emoji_freq = {}
# for message in df['message']:
#     emojis = count_emojis(message)
#     for emoji in emojis:
#         if emoji in emoji_freq:
#             emoji_freq[emoji] += 1
#         else:
#             emoji_freq[emoji] = 1

# emoji_df = pd.DataFrame({'Emoji': list(emoji_freq.keys()), 'Frequency': list(emoji_freq.values())})
# emoji_df = emoji_df.sort_values(by='Frequency', ascending=False)

# print(emoji_df)

# %%
df
# Out:
#                                           user_message        message_date  \
# 0                 Group creator created group "PTDORM" 2022-12-18 13:19:00
# 1                                       You were added 2022-12-18 13:19:00
# 2    Sayeed Hossain: Logo'r sathe theme ta jacce na... 2023-04-18 01:54:00
# 3                Sayeed Hossain: Make it more natural😅 2023-04-18 01:55:00
# 4                          Akash Ghosh: Mese keo asen? 2023-04-18 15:25:00
# ..                                                 ...                 ...
# 913  Ratul: Vai meal debo apnar ajke raat e??@88016... 2023-08-28 17:36:00
# 914                               Prottoy Vai Asl: nah 2023-08-28 17:38:00
# 915  Badhon Vai: https://fb.watch/mIEV565mlr/?mibex... 2023-08-29 00:39:00
# 916                   Prottoy Vai Asl: <Media omitted> 2023-08-29 00:46:00
# 917                   Prottoy Vai Asl: <Media omitted> 2023-08-29 00:51:00
#
#                                                message                user  \
# 0                 Group creator created group "PTDORM"  group_notification
# 1                                       You were added  group_notification
# 2                    Logo'r sathe theme ta jacce na...      Sayeed Hossain
# 3                                Make it more natural😅      Sayeed Hossain
# 4                                       Mese keo asen?         Akash Ghosh
# ..                                                 ...                 ...
# 913  Ratul: Vai meal debo apnar ajke raat e??@88016...               Ratul
# 914                               Prottoy Vai Asl: nah     Prottoy Vai Asl
# 915       https://fb.watch/mIEV565mlr/?mibextid=Nif5oz          Badhon Vai
# 916                   Prottoy Vai Asl: <Media omitted>     Prottoy Vai Asl
# 917                   Prottoy Vai Asl: <Media omitted>     Prottoy Vai Asl
#
#      year     month  day  hour  minute
# 0    2022  December   18    13      19
# 1    2022  December   18    13      19
# 2    2023     April   18     1      54
# 3    2023     April   18     1      55
# 4    2023     April   18    15      25
# ..    ...       ...  ...   ...     ...
# 913  2023    August   28    17      36
# 914  2023    August   28    17      38
# 915  2023    August   29     0      39
# 916  2023    August   29     0      46
# 917  2023    August   29     0      51
#
# [918 rows x 9 columns]

# %%
df['month_num'] = df['message_date'].dt.month
timeline = df.groupby(['year','month_num','month']).count()['message'].reset_index()

# %%
times=[]
for i in range(timeline.shape[0]):
    times.append(timeline['month'][i]+"-"+str(timeline['year'][i]))
    
timeline['time'] = times
plt.plot(timeline['time'],timeline['message'])
plt.show()

# %%
df['only_date'] = df['message_date'].dt.date
daily_timeline = df.groupby('only_date').count()['message'].reset_index()
plt.plot(daily_timeline['only_date'],daily_timeline['message'])
